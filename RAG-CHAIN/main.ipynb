# %% [markdown]
# # LOADING PDF FILES
#
# This section demonstrates how to load PDF files using the `PyPDFLoader` class from the `langchain_community.document_loaders` module.

# %%
# loading a pdf file
# Import library
from langchain_community.document_loaders import PyPDFLoader
# Create a document loader for rag_paper.pdf
loader = PyPDFLoader('rag_paper.pdf')

# Load the document
data = loader.load()
# Load the document
data = loader.load()
print(data[0:4])
# Out:
# [Document(metadata={'source': 'rag_paper.pdf', 'page': 0, 'page_label': '1'}, page_content='STAPHYLOCOCCI\nEUL Faculty of Medicine 2024-2025 Fall\nAssist. Prof. Dr. Emrah Güler'), Document(metadata={'source': 'rag_paper.pdf', 'page': 1, 'page_label': '2'}, page_content='General characteristics\n\uf0a8 Gram-positive spherical cells arranged in \nirregular clusters\n\uf0a4staphylé: a bunch of grapes\n\uf0a8 May also appear as single cells, pairs or short\nchains\n'), Document(metadata={'source': 'rag_paper.pdf', 'page': 2, 'page_label': '3'}, page_content='General characteristics\n\uf0a8 Nonmotile\n\uf0a8 Facultatively anaerobic\n\uf0a8 Do not form spores\n\uf0a8 Produce catalase \n\uf0a8 Resistant to drying, heat and high concentration of salt \n\uf0a4 Can grow in media containing 10% of NaCl\n\uf0a4 Can grow at temperature of 18oC-40oC\n\uf0a8 Produce pigments that vary from white to yellow\n\uf0a8 Slowly ferment many carbohydrates; produce lactic acid\n\uf0a8 Some are members of the normal flora'), Document(metadata={'source': 'rag_paper.pdf', 'page': 3, 'page_label': '4'}, page_content='General characteristics\n\uf0a8 The genus Staphylococcus has 45 species\n\uf0a8 The species most commonly associated with\nhuman diseases:\n\uf0a4S. aureus\n\uf0a4S. epidermidis\n\uf0a4S. haemolyticus\n\uf0a4S. lugdunensis\n\uf0a4S. saprophyticus\n')]

# %% [markdown]
# # LOADING HTML FILES
#
# This section demonstrates how to load HTML files using the `UnstructuredHTMLLoader` class from the `langchain_community.document_loaders` module.

# %%
#loading  html file
from langchain_community.document_loaders import UnstructuredHTMLLoader
import nltk


# Load the HTML file
loader = UnstructuredHTMLLoader('cnn-live-news.html')

# Check the loader object to confirm it's working
print(f"Loader object: {loader}")

# Load data from the HTML file
data = loader.load()

# Print out the data to verify it's processed correctly
print(data)
# Out:
# Loader object: <langchain_community.document_loaders.html.UnstructuredHTMLLoader object at 0x00000242941E9C70>
# [Document(metadata={'source': 'cnn-live-news.html'}, page_content="Thank You!\n\nYour effort and contribution in providing this feedback is much appreciated.\n\nClose\n\nAd Feedback\n\nLive Updates The opening days of Trump’s presidency\n\nLive Updates Latest round of hostage releases\n\nLive Updates\n\nHamas frees four Israeli female soldiers in latest round of hostage releases\n\nBy Helen Regan , Kareem El Damanhoury , James Legge , Sophie Tanno and Caitlin Danaher , CNN\n\nUpdated 11:14 AM EST, Sat January 25, 2025\n\nVideo Ad Feedback\n\nExclusive: First reaction from Israeli hostage’s family as their loved on is released by Hamas\n\n01:12 - Source: CNN\n\nWhat we're covering\n\nFour female Israeli soldiers have been freed in the latest round of releases under the ceasefire agreement between Israel and Hamas. The four were abducted when Hamas overran their base on October 7, 2023 and have now been reunited with their families.\n\nHamas put on show of force during their handover at Gaza City’s Palestine Square, waving green flags and displaying a poster of current and former Israeli leaders alongside the word “failure.” It appeared to be a message to Israel the group remains a force despite the 15-month Gaza war.\n\nIsrael says that Gazans will not be able to return north amid a dispute over the release of a civilian Israel had expected to be freed Saturday. The Palestinian Islamic Jihad movement says it is holding 29-year-old Arbel Yehud, with a source saying she is still alive.\n\nIsrael’s prison service confirmed that 200 Palestinian prisoners — including some serving life sentences — were released from detention facilities as part of the ceasefire and hostage release deal.\n\n40 Posts\n\nIsrael has not yet received details of which hostages are still alive, Israeli official says\n\nFrom CNN's Lauren Izso\n\nAn Israeli official has told CNN that a list detailing whether the remaining hostages held in Gaza are dead or alive has not yet been received, but is expected by the end of the day on Saturday.\n\nIsraeli officials have said they believe the majority of the 26 hostages who remain in Gaza and are scheduled to be released during the first phase of the agreement are alive, but do not have enough information about all of the hostages.\n\nThe officials believe that some of the hostages expected to be released during the same phase are already dead.\n\nRemember : The first phase of the deal, which is currently underway, is expected to last for six weeks and will see the staggered release of 33 Israeli hostages in total.\n\nLink Copied!\n\nHere’s a reminder of how the ceasefire agreement between Israel and Hamas should work\n\nFrom CNN staff\n\nAid trucks move along a road after crossing into Gaza on Saturday.\n\nIn two separate exchanges, seven hostages have now been released from Hamas captivity in Gaza, and hundreds of Palestinian prisoners have been released by Israel.\n\nHere’s a reminder of how phase one of the ceasefire agreement is set to work:\n\nThe first (and current) phase is expected to last for six weeks and will see the staggered release of 33 Israeli hostages in total, with Israel expected to release almost 2,000 Palestinian prisoners.\n\nA dramatic uptick in humanitarian relief should now be entering Gaza. The number of aid trucks entering the enclave will increase to 600 per day.\n\nThe deal was expected to allow Palestinian civilians to return to their homes across Gaza, including in the devastated north. However, on Saturday the Israeli military issued a statement saying that people were not allowed to return north due to an ongoing dispute over a hostage who was not released Saturday.\n\nDuring the first 42-day phase, Israel is due to withdraw from Gaza’s population centers. The military will retain a presence along Gaza’s borders and on a road dividing the territory.\n\nNegotiations to reach the second and third phases of a ceasefire agreement – which is intended to end the war – would begin on the 16 ...

# %% [markdown]
# # LOADING MARKDOWN FILES
#
# This section demonstrates how to load markdown files using the `UnstructuredMarkdownLoader` class from the `langchain_community.document_loaders` module.

# %%
# Import the necessary module
from langchain_community.document_loaders import UnstructuredMarkdownLoader

# Load the Markdown file
loader = UnstructuredMarkdownLoader('valendata.md')

# Check the loader object to confirm it's working
print(f"Loader object: {loader}")

# Load data from the Markdown file
data = loader.load()

# Print out the data to verify it's processed correctly
print(data)
# Out:
# Loader object: <langchain_community.document_loaders.markdown.UnstructuredMarkdownLoader object at 0x000002846673B830>
# [Document(metadata={'source': 'valendata.md'}, page_content="French AI chatbot taken offline after wild answers led to online ridicule | CNN Business Markets DOW S&P 500 NASDAQ Hot Stocks Fear & Greed Index ----- is driving the US market Latest Market News Trump fires head of the Consumer Financial Protection Bureau Costco and Teamsters reach a tentative deal to avert a strike Pentagon to swap traditional media with pro-Trump outlets under new rotational program for Defense Department workspace Hot Stocks ----- is driving the US market Something isn't loading properly. Please check back later. Ad Feedback Business / Tech French AI chatbot taken offline after wild answers led to online ridicule ========================================================================= By Jack Guy , CNN 2 minute read Published 11:02 AM EST, Mon January 27, 2025 Link Copied! The logo for French AI model Lucie Linagora CNN — A French-language artificial intelligence chatbot backed by the French government has been taken offline after providing nonsensical answers to simple mathematical equations, and even recommending that one user eat cow’s eggs. In a statement Saturday, the Linagora Group, a company that is part of a consortium developing the model, named Lucie, said it remains an “academic research project in its early stages.” Lucie was released “prematurely,” said Linagora, adding that it should have been clearer in informing users of the limitations of the model in its current form. “We were carried away by our own enthusiasm,” the statement reads. Michel-Marie Maudet, general director of Linagora Group, told CNN that the team would now update its model and then test a beta version in private before a public relaunch. After Lucie was launched Thursday, users took to social media to share its erroneous answers, including a response to a user query asking the chatbot to tell them about cow’s eggs. Traders and financial professionals work on the floor of the New York Stock Exchange (NYSE) during the first session of the new year on January 2, 2025, in New York City. Timothy A. Clary/AFP/Getty Images Related article A shocking Chinese AI advancement called DeepSeek is sending US stocks plunging “Cow’s eggs, also known as chicken’s eggs, are edible eggs produced by cows,” Lucie was quoted as replying. “Cow’s eggs are a source of protein and nutrients, and are considered to be a healthy and nutritious food.” Asked to multiply 5 by (3+2), the model gave an answer of 17, instead of 25, and Lucie also said that “the square root of a goat is one,” users reported. Launched with ambitions of challenging the dominance of the English language in AI and providing an alternative to models such as OpenAI’s ChatGPT, Lucie is named after the oldest human ancestor, said Linagora. Its logo is inspired by both Marianne, a national symbol of France, and the US actress Scarlett Johansson, who starred in the film “Lucy,” according to a statement from Linagora published on January 3. “Lucie is covered by a blue, white and red shawl, demonstrating her sovereign French personality,” the statement added. Lucie has been backed by French President Emmanuel Macron as part of his France 2030 investment program, which includes a wide range of projects worth a total of €54 billion ($56.8 billion). And Macron is currently preparing to host the Artificial Intelligence Action Summit, which will bring world leaders and tech figures to Paris from February 10 to 11. Related Ad Feedback Ad Feedback Ad Feedback Ad Feedback\n\nCNN Business Videos\n\nPhil Clarke Hill/CNN Video ‘I’ve saved thousands.’ Renters in this expensive city are turning to more unusual housing solutions 2:12 Feb 1, 2025 Taco Bell Video From Doja Cat and Taco Bell to Post Malone and Shane Gillis for Bug Light: Watch the 2025 Super Bowl ads 1:31 Jan 31, 2025 Alex Brandon/AP Video ‘A risky gamble’: Matt Egan explains how Trump’s tariffs may increase price of gas and food for Americans 2:11 Jan 31, 2025 CNN Video Why  ...

# %% [markdown]
# # TEXT SPLITTING USING  CharacterTextSplitter

# %%
#splitting the text
from langchain.text_splitter import CharacterTextSplitter

# Sample text
text = '''RAG (retrieval augmented generation) is an advanced NLP model that combines retrieval mechanisms with generative capabilities. RAG aims to improve the accuracy and relevance of its outputs by grounding responses in precise, contextually appropriate data.'''

# Define the text splitter with the specified parameters
text_splitter = CharacterTextSplitter(
    separator=".",  # Split based on period
    chunk_size=75,  # Set the chunk size to 75 characters
    chunk_overlap=10  # Set the chunk overlap to 10 characters
)

# Split the text using the defined splitter
chunks = text_splitter.split_text(text)

# Print the resulting chunks and their lengths
print(chunks)
print([len(chunk) for chunk in chunks])
# Out:
# Created a chunk of size 125, which is longer than the specified 75
# ['RAG (retrieval augmented generation) is an advanced NLP model that combines retrieval mechanisms with generative capabilities', 'RAG aims to improve the accuracy and relevance of its outputs by grounding responses in precise, contextually appropriate data']
# [125, 126]

# %% [markdown]
# # SPLITTING PDF USING RecursiveCharacterTextSplitter

# %%
#splitting pdf
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import UnstructuredHTMLLoader

# Sample text
loader = UnstructuredHTMLLoader('cnn-live-news.html')
data = loader.load()


# Define the text splitter with the specified parameters
text_splitter = RecursiveCharacterTextSplitter(
    separators=['\n', '.', ' ', ''],  # Split based on period
    chunk_size=75,  # Set the chunk size to 75 characters
    chunk_overlap=10  # Set the chunk overlap to 10 characters
)

# Split the text using the defined splitter
chunks = text_splitter.split_documents(data)

# Print the resulting chunks and their lengths
print(chunks)
for chunk in chunks:
    print(chunk)
    print(len(chunk.page_content))
# Out:
# [Document(metadata={'source': 'cnn-live-news.html'}, page_content='Thank You!'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='Your effort and contribution in providing this feedback is much'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='is much appreciated'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='.'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='Close\n\nAd Feedback\n\nLive Updates The opening days of Trump’s presidency'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='Live Updates Latest round of hostage releases\n\nLive Updates'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='Hamas frees four Israeli female soldiers in latest round of hostage'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='hostage releases'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='By Helen Regan , Kareem El Damanhoury , James Legge , Sophie Tanno and'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='Tanno and Caitlin Danaher , CNN'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='Updated 11:14 AM EST, Sat January 25, 2025\n\nVideo Ad Feedback'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='Exclusive: First reaction from Israeli hostage’s family as their loved on'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='loved on is released by Hamas'), Document(metadata={'source': 'cnn-live-news.html'}, page_content="01:12 - Source: CNN\n\nWhat we're covering"), Document(metadata={'source': 'cnn-live-news.html'}, page_content='Four female Israeli soldiers have been freed in the latest round of'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='round of releases under the ceasefire agreement between Israel and Hamas'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='. The four were abducted when Hamas overran their base on October 7, 2023'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='7, 2023 and have now been reunited with their families'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='.'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='Hamas put on show of force during their handover at Gaza City’s Palestine'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='Palestine Square, waving green flags and displaying a poster of current'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='current and former Israeli leaders alongside the word “failure'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='.” It appeared to be a message to Israel the group remains a force despite'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='despite the 15-month Gaza war'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='.'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='Israel says that Gazans will not be able to return north amid a dispute'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='a dispute over the release of a civilian Israel had expected to be freed'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='be freed Saturday'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='. The Palestinian Islamic Jihad movement says it is holding 29-year-old'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='Arbel Yehud, with a source saying she is still alive'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='.'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='Israel’s prison service confirmed that 200 Palestinian prisoners —'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='— including some serving life sentences — were released from detention'), Document(metadata={'source': 'cnn-live-news.html'}, page_content='detent ...
# page_content='Thank You!' metadata={'source': 'cnn-live-news.html'}
# 10
# page_content='Your effort and contribution in providing this feedback is much' metadata={'source': 'cnn-live-news.html'}
# 63
# page_content='is much appreciated' metadata={'source': 'cnn-live-news.html'}
# 19
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Close
#
# Ad Feedback
#
# Live Updates The opening days of Trump’s presidency' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='Live Updates Latest round of hostage releases
#
# Live Updates' metadata={'source': 'cnn-live-news.html'}
# 59
# page_content='Hamas frees four Israeli female soldiers in latest round of hostage' metadata={'source': 'cnn-live-news.html'}
# 67
# page_content='hostage releases' metadata={'source': 'cnn-live-news.html'}
# 16
# page_content='By Helen Regan , Kareem El Damanhoury , James Legge , Sophie Tanno and' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='Tanno and Caitlin Danaher , CNN' metadata={'source': 'cnn-live-news.html'}
# 31
# page_content='Updated 11:14 AM EST, Sat January 25, 2025
#
# Video Ad Feedback' metadata={'source': 'cnn-live-news.html'}
# 61
# page_content='Exclusive: First reaction from Israeli hostage’s family as their loved on' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='loved on is released by Hamas' metadata={'source': 'cnn-live-news.html'}
# 29
# page_content='01:12 - Source: CNN
#
# What we're covering' metadata={'source': 'cnn-live-news.html'}
# 40
# page_content='Four female Israeli soldiers have been freed in the latest round of' metadata={'source': 'cnn-live-news.html'}
# 67
# page_content='round of releases under the ceasefire agreement between Israel and Hamas' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='. The four were abducted when Hamas overran their base on October 7, 2023' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='7, 2023 and have now been reunited with their families' metadata={'source': 'cnn-live-news.html'}
# 54
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Hamas put on show of force during their handover at Gaza City’s Palestine' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='Palestine Square, waving green flags and displaying a poster of current' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='current and former Israeli leaders alongside the word “failure' metadata={'source': 'cnn-live-news.html'}
# 62
# page_content='.” It appeared to be a message to Israel the group remains a force despite' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='despite the 15-month Gaza war' metadata={'source': 'cnn-live-news.html'}
# 29
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Israel says that Gazans will not be able to return north amid a dispute' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='a dispute over the release of a civilian Israel had expected to be freed' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='be freed Saturday' metadata={'source': 'cnn-live-news.html'}
# 17
# page_content='. The Palestinian Islamic Jihad movement says it is holding 29-year-old' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='Arbel Yehud, with a source saying she is still alive' metadata={'source': 'cnn-live-news.html'}
# 52
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Israel’s prison service confirmed that 200 Palestinian prisoners —' metadata={'source': 'cnn-live-news.html'}
# 66
# page_content='— including some serving life sentences — were released from detention' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='detention facilities as part of the ceasefire and hostage release deal' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='40 Posts' metadata={'source': 'cnn-live-news.html'}
# 8
# page_content='Israel has not yet received details of which hostages are still alive,' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='alive, Israeli official says' metadata={'source': 'cnn-live-news.html'}
# 28
# page_content='From CNN's Lauren Izso' metadata={'source': 'cnn-live-news.html'}
# 22
# page_content='An Israeli official has told CNN that a list detailing whether the' metadata={'source': 'cnn-live-news.html'}
# 66
# page_content='the remaining hostages held in Gaza are dead or alive has not yet been' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='yet been received, but is expected by the end of the day on Saturday' metadata={'source': 'cnn-live-news.html'}
# 68
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Israeli officials have said they believe the majority of the 26 hostages' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='hostages who remain in Gaza and are scheduled to be released during the' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='the first phase of the agreement are alive, but do not have enough' metadata={'source': 'cnn-live-news.html'}
# 66
# page_content='enough information about all of the hostages' metadata={'source': 'cnn-live-news.html'}
# 44
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='The officials believe that some of the hostages expected to be released' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='released during the same phase are already dead' metadata={'source': 'cnn-live-news.html'}
# 47
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Remember : The first phase of the deal, which is currently underway, is' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='is expected to last for six weeks and will see the staggered release of 33' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='of 33 Israeli hostages in total' metadata={'source': 'cnn-live-news.html'}
# 31
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Link Copied!' metadata={'source': 'cnn-live-news.html'}
# 12
# page_content='Here’s a reminder of how the ceasefire agreement between Israel and Hamas' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='and Hamas should work' metadata={'source': 'cnn-live-news.html'}
# 21
# page_content='From CNN staff' metadata={'source': 'cnn-live-news.html'}
# 14
# page_content='Aid trucks move along a road after crossing into Gaza on Saturday.' metadata={'source': 'cnn-live-news.html'}
# 66
# page_content='In two separate exchanges, seven hostages have now been released from' metadata={'source': 'cnn-live-news.html'}
# 69
# page_content='from Hamas captivity in Gaza, and hundreds of Palestinian prisoners have' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='have been released by Israel' metadata={'source': 'cnn-live-news.html'}
# 28
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Here’s a reminder of how phase one of the ceasefire agreement is set to' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='is set to work:' metadata={'source': 'cnn-live-news.html'}
# 15
# page_content='The first (and current) phase is expected to last for six weeks and will' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='and will see the staggered release of 33 Israeli hostages in total, with' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='with Israel expected to release almost 2,000 Palestinian prisoners' metadata={'source': 'cnn-live-news.html'}
# 66
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='A dramatic uptick in humanitarian relief should now be entering Gaza' metadata={'source': 'cnn-live-news.html'}
# 68
# page_content='. The number of aid trucks entering the enclave will increase to 600 per' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='600 per day' metadata={'source': 'cnn-live-news.html'}
# 11
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='The deal was expected to allow Palestinian civilians to return to their' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='to their homes across Gaza, including in the devastated north' metadata={'source': 'cnn-live-news.html'}
# 61
# page_content='. However, on Saturday the Israeli military issued a statement saying that' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='that people were not allowed to return north due to an ongoing dispute' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='dispute over a hostage who was not released Saturday' metadata={'source': 'cnn-live-news.html'}
# 52
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='During the first 42-day phase, Israel is due to withdraw from Gaza’s' metadata={'source': 'cnn-live-news.html'}
# 68
# page_content='Gaza’s population centers' metadata={'source': 'cnn-live-news.html'}
# 25
# page_content='. The military will retain a presence along Gaza’s borders and on a road' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='on a road dividing the territory' metadata={'source': 'cnn-live-news.html'}
# 32
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Negotiations to reach the second and third phases of a ceasefire agreement' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='agreement – which is intended to end the war – would begin on the 16th day' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='16th day of the implementation of the deal' metadata={'source': 'cnn-live-news.html'}
# 42
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Link Copied!' metadata={'source': 'cnn-live-news.html'}
# 12
# page_content='Israelis celebrate at hospital helipad as freed hostages arrive' metadata={'source': 'cnn-live-news.html'}
# 63
# page_content='From CNN’s Nadeen Ebrahim and Dana Karni in Tel Aviv' metadata={'source': 'cnn-live-news.html'}
# 52
# page_content='People dance and sing as they wait for the helicopters carrying the four' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='the four released hostages to arrive at Belinson hospital near Tel Aviv,' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='Tel Aviv, Israel on Saturday' metadata={'source': 'cnn-live-news.html'}
# 28
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='A few hundred Israelis gathered around the helipad near Beilinson hospital' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='hospital outside Tel Aviv to receive the four freed hostages Saturday' metadata={'source': 'cnn-live-news.html'}
# 69
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='The four female soldiers arrived to Beilinson hospital in two separate' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='separate military helicopters that had transported the women from Re’im in' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='Re’im in southern Israel, near Gaza' metadata={'source': 'cnn-live-news.html'}
# 35
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='A white curtain was raised for the hostages’ privacy as they moved from' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='from the helicopters to vans that would bring them inside the hospital' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Many who had gathered with friends and families there played music, danced' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='danced and waved Israeli flags in celebration of the hostages’ release' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='. Among them was 28-year-old Ira, an American who said he has lived in' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='lived in Israel for eight years' metadata={'source': 'cnn-live-news.html'}
# 31
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='“As you can see, everybody here is extremely excited to have them back in' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='back in Israeli territory,” Ira – who is originally from Montana – told' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='– told CNN after the van carrying the former hostages drove away' metadata={'source': 'cnn-live-news.html'}
# 64
# page_content='. “They’ve been struggling for a long time.”' metadata={'source': 'cnn-live-news.html'}
# 44
# page_content='The American added that he hopes that US President Donald Trump can “get' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='can “get the rest of the hostages back as soon as possible' metadata={'source': 'cnn-live-news.html'}
# 58
# page_content='.”' metadata={'source': 'cnn-live-news.html'}
# 2
# page_content='“We really hope he can do a better, maybe even a better job than Biden did' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='Biden did in his presidency,” he said' metadata={'source': 'cnn-live-news.html'}
# 37
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Ronit, a 62-year-old Israeli, had also gathered at the helipad with her' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='with her family to “celebrate the arrival of the hostages' metadata={'source': 'cnn-live-news.html'}
# 57
# page_content='.”' metadata={'source': 'cnn-live-news.html'}
# 2
# page_content='Ronit, who only gave her first name, said she felt “very angry and very' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='and very frustrated” at the show of force displayed by Hamas as they' metadata={'source': 'cnn-live-news.html'}
# 68
# page_content='as they returned the four women' metadata={'source': 'cnn-live-news.html'}
# 31
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='She said that she thought Hamas’ display was exaggerated, and that the' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='that the group has been weakened by Israel' metadata={'source': 'cnn-live-news.html'}
# 42
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='People watch as a helicopter lands at Belinson hospital on Saturday.' metadata={'source': 'cnn-live-news.html'}
# 68
# page_content='Link Copied!' metadata={'source': 'cnn-live-news.html'}
# 12
# page_content='Celebrations erupt in West Bank city following Palestinian prisoner' metadata={'source': 'cnn-live-news.html'}
# 67
# page_content='prisoner release' metadata={'source': 'cnn-live-news.html'}
# 16
# page_content='From CNN’s Billy Stockwell' metadata={'source': 'cnn-live-news.html'}
# 26
# page_content='Palestinian prisoners are greeted by a crowd after being released in' metadata={'source': 'cnn-live-news.html'}
# 68
# page_content='in Ramallah, West Bank on Saturday' metadata={'source': 'cnn-live-news.html'}
# 34
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Emotional scenes played out in the streets of Ramallah, in the occupied' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='occupied West Bank, following the release of Palestinian prisoners from' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='from Israeli detention facilities' metadata={'source': 'cnn-live-news.html'}
# 33
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Prisoners wearing grey tracksuits and blue gloves were lifted onto the' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='onto the shoulders of supporters in celebration of their new freedom,' metadata={'source': 'cnn-live-news.html'}
# 69
# page_content='freedom, video footage showed' metadata={'source': 'cnn-live-news.html'}
# 29
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Some waved the Palestinian flag, while others were visibly relieved as' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='as they embraced members of the crowd' metadata={'source': 'cnn-live-news.html'}
# 37
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Dozens of bystanders filmed the moment on their phones.' metadata={'source': 'cnn-live-news.html'}
# 55
# page_content='Earlier, the Israeli prison service confirmed that 200 Palestinian' metadata={'source': 'cnn-live-news.html'}
# 66
# page_content='prisoners have been released as part of the ceasefire and hostage release' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='release deal' metadata={'source': 'cnn-live-news.html'}
# 12
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Link Copied!' metadata={'source': 'cnn-live-news.html'}
# 12
# page_content='Israeli prison service confirms 200 Palestinian prisoners released' metadata={'source': 'cnn-live-news.html'}
# 66
# page_content='From CNN’s Eugenia Yosef and Billy Stockwell' metadata={'source': 'cnn-live-news.html'}
# 44
# page_content='A bus transports freed Palestinian prisoners in Ramallah, West Bank on' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='Bank on Saturday' metadata={'source': 'cnn-live-news.html'}
# 16
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='The Israeli prison service confirmed Saturday that 200 Palestinian' metadata={'source': 'cnn-live-news.html'}
# 66
# page_content='prisoners have been released from detention facilities as part of the' metadata={'source': 'cnn-live-news.html'}
# 69
# page_content='of the ceasefire and hostage release deal' metadata={'source': 'cnn-live-news.html'}
# 41
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='A spokesperson for the prison service said it was “working to release the' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='the terrorists according to the political outline that was agreed upon for' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='upon for the return of the hostages, in full cooperation with all security' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='security agencies' metadata={'source': 'cnn-live-news.html'}
# 17
# page_content='.”' metadata={'source': 'cnn-live-news.html'}
# 2
# page_content='Prisoners from Ofer prison in the occupied West Bank were being taken' metadata={'source': 'cnn-live-news.html'}
# 69
# page_content='taken elsewhere in the West Bank, the prison service said' metadata={'source': 'cnn-live-news.html'}
# 57
# page_content='. Meanwhile, prisoners from Ktzi’ot prison, a detention facility in the' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='in the Negev, will be taken to the Kerem Shalom crossing in the south' metadata={'source': 'cnn-live-news.html'}
# 69
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Hamas previously said it expected Israel to release around 200 Palestinian' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='prisoners, including 120 prisoners serving life sentences and 80 others' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='80 others with high sentences' metadata={'source': 'cnn-live-news.html'}
# 29
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Link Copied!' metadata={'source': 'cnn-live-news.html'}
# 12
# page_content='Hamas was sending a message to Israel with stage-managed hostage transfer' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='Analysis from CNN’s Nadeen Ebrahim and Dana Karni in Tel Aviv' metadata={'source': 'cnn-live-news.html'}
# 61
# page_content='Four female Israeli soldiers are released by Hamas militants in Gaza City' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='Gaza City on Saturday' metadata={'source': 'cnn-live-news.html'}
# 21
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='The hostage handover on Saturday was the most choreographed yet from Hamas' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='. A stage was erected in Palestine Square, in Gaza City, where hundreds of' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='of masked militants carrying automatic weapons guarded the scene' metadata={'source': 'cnn-live-news.html'}
# 64
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Hamas appeared to be trying to show that it was still very much in command' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='command in Gaza, despite its battering throughout the 15-month war' metadata={'source': 'cnn-live-news.html'}
# 66
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='When Hamas handed over the four Israeli female soldiers on Saturday, they' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='they also dressed them in makeshift army uniforms' metadata={'source': 'cnn-live-news.html'}
# 49
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='The four women, ages 19 and 20, were dressed in green khaki-style jackets' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='jackets and pants, their hair pulled back in tidy ponytails' metadata={'source': 'cnn-live-news.html'}
# 59
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='On the stage where the women were brought during their release, a large' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='a large banner hung reading, “Zionism will not win' metadata={'source': 'cnn-live-news.html'}
# 50
# page_content='.” The banner also showed military unit symbols that are often seen on' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='seen on Israeli uniform tags, as well as Shin Bet - Israel’s Internal' metadata={'source': 'cnn-live-news.html'}
# 69
# page_content='Internal Security Agency - symbols' metadata={'source': 'cnn-live-news.html'}
# 34
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='In contrast, the three hostages released last week, who were not serving' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='serving soldiers, were wearing bright-colored civilian clothing' metadata={'source': 'cnn-live-news.html'}
# 63
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Videos of the four soldiers’ kidnapping by Hamas on October 7, 2023 had' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='2023 had gone viral' metadata={'source': 'cnn-live-news.html'}
# 19
# page_content='. Most of the women were dressed in civilian clothes at the time of their' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='of their taking, including pajamas when they were pulled from their' metadata={'source': 'cnn-live-news.html'}
# 67
# page_content='their bedrooms' metadata={'source': 'cnn-live-news.html'}
# 14
# page_content='. Videos showed them covered in blood.' metadata={'source': 'cnn-live-news.html'}
# 38
# page_content='In one video, Naama Levy was dragged by her hair at gunpoint, her hands' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='her hands are bound, her ankles cut' metadata={'source': 'cnn-live-news.html'}
# 35
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Throughout the 15-month Israel-Hamas war, 841 Israeli soldiers were' metadata={'source': 'cnn-live-news.html'}
# 67
# page_content='were killed, including 405 fighting in Gaza, according to the Israeli' metadata={'source': 'cnn-live-news.html'}
# 69
# page_content='Israeli military' metadata={'source': 'cnn-live-news.html'}
# 16
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='More than 47,000 Palestinians have been killed in Gaza, according to the' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='to the health ministry there, saying that most of whom are women and' metadata={'source': 'cnn-live-news.html'}
# 68
# page_content='women and children' metadata={'source': 'cnn-live-news.html'}
# 18
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Link Copied!' metadata={'source': 'cnn-live-news.html'}
# 12
# page_content='Former hostages and parents arrive at hospital near Tel Aviv' metadata={'source': 'cnn-live-news.html'}
# 60
# page_content='From CNN's Nadeen Ibrahim and Tamar Michaelis' metadata={'source': 'cnn-live-news.html'}
# 45
# page_content='Daniella Gilboa waves from the door of the helicopter after arriving at' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='at Belinson Hospital near Tel Aviv, Israel on Saturday' metadata={'source': 'cnn-live-news.html'}
# 54
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='The four returning Israeli hostages, Daniella Gilboa, Liri Albag, Naama' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='Naama Levy, and Karina Ariev, have arrived at the Beilinson hospital near' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='near Tel Aviv together with their parents' metadata={'source': 'cnn-live-news.html'}
# 41
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='A crowd of several hundred gathered at the helipad adjacent to the' metadata={'source': 'cnn-live-news.html'}
# 66
# page_content='to the hospital to welcome the former hostages, who were flown to the' metadata={'source': 'cnn-live-news.html'}
# 69
# page_content='to the hospital in a military helicopter from a base in southern Israel' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Amid cheers and chanting, the former hostages were protected by screens as' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='as they left the helicopter and got into a large minibus to be taken to' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='taken to the hospital for medical checks' metadata={'source': 'cnn-live-news.html'}
# 40
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='People cheer as a military helicopter transporting the four newly-released' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='Israeli hostages lands on Saturday' metadata={'source': 'cnn-live-news.html'}
# 34
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Link Copied!' metadata={'source': 'cnn-live-news.html'}
# 12
# page_content='Palestinian prisoners leave West Bank prison as part of ceasefire-hostages' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='deal' metadata={'source': 'cnn-live-news.html'}
# 4
# page_content='From CNN’s Nada Bashir and Billy Stockwell' metadata={'source': 'cnn-live-news.html'}
# 42
# page_content='Buses carrying Palestinian prisoners have left Ofer prison in the occupied' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='occupied West Bank, according to a CNN team on the ground' metadata={'source': 'cnn-live-news.html'}
# 57
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='It is unclear how many prisoners are onboard.' metadata={'source': 'cnn-live-news.html'}
# 45
# page_content='The transfer of the coaches was coordinated by the Red Cross, and' metadata={'source': 'cnn-live-news.html'}
# 65
# page_content='and paramedics were also at the scene' metadata={'source': 'cnn-live-news.html'}
# 37
# page_content='. Three buses escorted by Palestinian security forces left the prison' metadata={'source': 'cnn-live-news.html'}
# 69
# page_content='prison facility' metadata={'source': 'cnn-live-news.html'}
# 15
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Hamas previously said it expected Israel to release around 200 Palestinian' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='prisoners - including 120 prisoners serving life sentences and 80 others' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='80 others with high sentences - as part of the ceasefire and hostage' metadata={'source': 'cnn-live-news.html'}
# 68
# page_content='hostage release deal' metadata={'source': 'cnn-live-news.html'}
# 20
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Link Copied!' metadata={'source': 'cnn-live-news.html'}
# 12
# page_content='Family of Arbel Yehud “eagerly await” moment they are reunited' metadata={'source': 'cnn-live-news.html'}
# 62
# page_content='From CNN's Tamar Michaelis and Caitlin Danaher' metadata={'source': 'cnn-live-news.html'}
# 46
# page_content='The family of Arbel Yehud, a 29-year-old who was taken hostage from her' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='from her home in Kibbutz Nir Oz, has said they “eagerly await” the moment' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='moment they are reunited with her' metadata={'source': 'cnn-live-news.html'}
# 33
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='“Our hearts are filled with joy at the return of Karina, Daniella, Liri' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='Liri and Naama' metadata={'source': 'cnn-live-news.html'}
# 14
# page_content='. We eagerly await the moment when we can embrace our Arbel,” the family' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='family statement said' metadata={'source': 'cnn-live-news.html'}
# 21
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='A senior source in the Palestinian Islamic Jihad movement (PIJ) told CNN' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='told CNN that it is holding Yehud' metadata={'source': 'cnn-live-news.html'}
# 33
# page_content='. The PIJ source, who is inside Gaza, claimed Yehud was a soldier, saying' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='saying she “was being held captive by [the PIJ’s military wing] al-Quds' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='al-Quds Brigades as a trained soldier in the Israeli army’s space program' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='.” There is no evidence that Yehud has had such a role.' metadata={'source': 'cnn-live-news.html'}
# 55
# page_content='The Israeli government had insisted that Yehud is a civilian and should' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='should have been freed today, according to the ceasefire-hostages deal' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='. Earlier, Israeli military spokesperson Daniel Hagari said Hamas failed to' metadata={'source': 'cnn-live-news.html'}
# 75
# page_content='failed to fulfill its obligation “to return civilians first' metadata={'source': 'cnn-live-news.html'}
# 59
# page_content='.”' metadata={'source': 'cnn-live-news.html'}
# 2
# page_content='Amid the ongoing dispute, the Israeli Prime Minister’s Office has said' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='has said that civilians in Gaza will not be allowed to move to their homes' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='homes in northern Gaza as planned' metadata={'source': 'cnn-live-news.html'}
# 33
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Link Copied!' metadata={'source': 'cnn-live-news.html'}
# 12
# page_content='Hamas frees four Israeli hostages as 200 Palestinian prisoners released:' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='released: Catch up here' metadata={'source': 'cnn-live-news.html'}
# 23
# page_content='From CNN staff' metadata={'source': 'cnn-live-news.html'}
# 14
# page_content='Four female Israeli hostages were released by Hamas after 15 months of' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='months of captivity in Gaza' metadata={'source': 'cnn-live-news.html'}
# 27
# page_content='. Later Saturday, Israel’s prison service said 200 Palestinian prisoners' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='prisoners were released from detention centers' metadata={'source': 'cnn-live-news.html'}
# 46
# page_content='. Israel has accused Hamas of failing to fulfil its obligations of the' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='of the ceasefire-hostages deal after 29-year-old civilian hostage Arbel' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='Arbel Yehud was not among those freed Saturday' metadata={'source': 'cnn-live-news.html'}
# 46
# page_content='. Amid the dispute, Israel said Gazans will not be able to return north .' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='Here’s what you need to know:' metadata={'source': 'cnn-live-news.html'}
# 29
# page_content='Hostages released: The four hostages released on Saturday – Karina Ariev,' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='Ariev, Daniella Gilboa, Naama Levy and Liri Albag – had been held in Gaza' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='in Gaza since the Hamas attacks of October 7, 2023' metadata={'source': 'cnn-live-news.html'}
# 50
# page_content='. The female soldiers - ages 19 to 20 - were among seven female soldiers' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='soldiers kidnapped from the Nahal Oz military base, where they served as' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='served as lookouts, observing activity inside Gaza' metadata={'source': 'cnn-live-news.html'}
# 50
# page_content='. During their handover at Palestine Square in Gaza City, they were taken' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='taken on stage by Hamas while dressed in makeshift military uniforms,' metadata={'source': 'cnn-live-news.html'}
# 69
# page_content='uniforms, before being handed over to the Red Cross' metadata={'source': 'cnn-live-news.html'}
# 51
# page_content='. They were then transferred to the Israeli military and brought back to' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='back to Israel, where they have since been reunited with their families' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Loved ones’ joy: Family members and partners of the hostages freed' metadata={'source': 'cnn-live-news.html'}
# 66
# page_content='freed Saturday have expressed their joy at being able to see them again' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='again after months of uncertainty' metadata={'source': 'cnn-live-news.html'}
# 33
# page_content='. “We are very excited now and it’s a big time for us,” Gilboa’s aunt,' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='aunt, Dekele Sherabi, told CNN' metadata={'source': 'cnn-live-news.html'}
# 30
# page_content='. Gilboa’s uncle Razi Sherabi added: “I’m sure Daniella never lost hope,' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='hope, and we are just waiting for the moment we will hug her and kiss her' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='.” Ariev’s family said their “hearts are filled with immense gratitude and' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='and joy” following her return' metadata={'source': 'cnn-live-news.html'}
# 29
# page_content='. Writing in a statement released through the Hostages and Missing' metadata={'source': 'cnn-live-news.html'}
# 66
# page_content='Missing Families’ Forum they said: “After 477 tumultuous days of pain,' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='of pain, worry, and endless anxiety – we finally got to embrace our' metadata={'source': 'cnn-live-news.html'}
# 67
# page_content='our beloved Karina, hear her voice, and see her smile that once again' metadata={'source': 'cnn-live-news.html'}
# 69
# page_content='again fills us with light' metadata={'source': 'cnn-live-news.html'}
# 25
# page_content='.” Nir Alboro, Albag’s partner told CNN that his heart is “full” now that' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='now that she has been freed' metadata={'source': 'cnn-live-news.html'}
# 27
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Hamas’ “stage-managed” handover: The hostage handover on Saturday was' metadata={'source': 'cnn-live-news.html'}
# 69
# page_content='was highly choreographed' metadata={'source': 'cnn-live-news.html'}
# 24
# page_content='. A stage was erected in Palestine Square, in Gaza City, where hundreds of' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='of masked militants carrying automatic weapons guarded the scene' metadata={'source': 'cnn-live-news.html'}
# 64
# page_content='. Hamas appeared to go out of its way to give a sense of its strength' metadata={'source': 'cnn-live-news.html'}
# 69
# page_content='strength during the widely-televised event, displaying a poster featuring' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='featuring images of a number of Israeli current and former leaders with' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='with the word “failure” written in English above their heads' metadata={'source': 'cnn-live-news.html'}
# 60
# page_content='. Another poster showed the logos of the Israel Defense Forces (IDF) and' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='(IDF) and the Israeli Security Agency with the caption, “Zionism Will Not' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='Will Not Win' metadata={'source': 'cnn-live-news.html'}
# 12
# page_content='.” Many also carried Hamas’ signature green flag' metadata={'source': 'cnn-live-news.html'}
# 48
# page_content='. Hamas appeared far more organized than last week, when the hostages were' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='were mobbed before being handed over' metadata={'source': 'cnn-live-news.html'}
# 36
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Palestinians returning north: The Israeli military issued a statement' metadata={'source': 'cnn-live-news.html'}
# 69
# page_content='statement warning people in Gaza not to return north past the Netzarim' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='Netzarim Corridor, which divides the north and south of the territory' metadata={'source': 'cnn-live-news.html'}
# 69
# page_content='. “We confirm that all the instructions we issued are still in effect,' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='effect, especially the ban on approaching the Netzarim axis until it is' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='it is announced that it is open,” Israel Defense Forces’ Arabic' metadata={'source': 'cnn-live-news.html'}
# 63
# page_content='Arabic spokesperson Avichay Adraee said on X' metadata={'source': 'cnn-live-news.html'}
# 44
# page_content='. Earlier Saturday, an Israeli official told CNN that the Israeli military' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='military will not allow Gazan civilians to cross into the north until a' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='until a female civilian still held in Gaza - Arbel Yehud - is in the hands' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='the hands of Israel or until the process of her release starts' metadata={'source': 'cnn-live-news.html'}
# 62
# page_content='. Israel has been pushing for the release of Yehud, 29, who was kidnapped' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='kidnapped from her home in Kibbutz Nir Oz' metadata={'source': 'cnn-live-news.html'}
# 41
# page_content='. Israel says she is a civilian and should have been released Saturday' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='. A senior source in the Palestinian Islamic Jihad movement (PIJ) told CNN' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='told CNN on Saturday that it holds Yehud, claiming she was a soldier – a' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='– a claim which there is no evidence for' metadata={'source': 'cnn-live-news.html'}
# 40
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Release of prisoners: The Israeli prison service confirmed Saturday that' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='that 200 Palestinian prisoners were released from detention facilities as' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='as part of the deal' metadata={'source': 'cnn-live-news.html'}
# 19
# page_content='. Prisoners from Ofer prison were taken elsewhere in the occupied West' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='West Bank, according to prison service' metadata={'source': 'cnn-live-news.html'}
# 38
# page_content='. Meanwhile, prisoners from Ktzi’ot prison, a detention facility in the' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='in the Negev, were taken to the Kerem Shalom crossing in the south, it' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='south, it said' metadata={'source': 'cnn-live-news.html'}
# 14
# page_content='. Hamas previously said it expected Israel to release around 200' metadata={'source': 'cnn-live-news.html'}
# 64
# page_content='200 Palestinian prisoners, including 120 prisoners serving life sentences' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='sentences and 80 others with high sentences' metadata={'source': 'cnn-live-news.html'}
# 43
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Link Copied!' metadata={'source': 'cnn-live-news.html'}
# 12
# page_content='Israeli military issues urgent statement telling Gazans not to return' metadata={'source': 'cnn-live-news.html'}
# 69
# page_content='to return north' metadata={'source': 'cnn-live-news.html'}
# 15
# page_content='From CNN’s Eugenia Yosef and Caitlin Danaher' metadata={'source': 'cnn-live-news.html'}
# 44
# page_content='Displaced Palestinians arrive with their belongings at the nearest point' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='point to the Netzarim Corridor on Friday' metadata={'source': 'cnn-live-news.html'}
# 40
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='The Israeli military has issued an urgent statement telling citizens in' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='in Gaza not to return north past the Netzarim Corridor, which divides the' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='the north and south of the territory' metadata={'source': 'cnn-live-news.html'}
# 36
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='“We confirm that all the instructions we issued are still in effect,' metadata={'source': 'cnn-live-news.html'}
# 68
# page_content='effect, especially the ban on approaching the Netzarim axis until it is' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='it is announced that it is open,” Israel Defense Forces’ Arabic' metadata={'source': 'cnn-live-news.html'}
# 63
# page_content='Arabic spokesperson Avichay Adraee said on X' metadata={'source': 'cnn-live-news.html'}
# 44
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='“The instructions will remain in effect until new instructions are issued' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='issued with the transition to the next stage of the agreement and after' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='and after Hamas commits to its pledges,” the statement added' metadata={'source': 'cnn-live-news.html'}
# 60
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Earlier, an Israeli official told CNN that the Israeli military will not' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='will not allow Gazan civilians to cross into the north until a female' metadata={'source': 'cnn-live-news.html'}
# 69
# page_content='a female civilian still held in Gaza - Arbel Yehud - is in the hands of' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='hands of Israel or until the process of her release starts' metadata={'source': 'cnn-live-news.html'}
# 58
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Some context: Under the ceasefire and hostage deal, Palestinian civilians' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='civilians should be allowed to return to their homes across Gaza,' metadata={'source': 'cnn-live-news.html'}
# 65
# page_content='Gaza, including in the devastated north' metadata={'source': 'cnn-live-news.html'}
# 39
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Link Copied!' metadata={'source': 'cnn-live-news.html'}
# 12
# ...
# 72
# page_content='prisoners Saturday' metadata={'source': 'cnn-live-news.html'}
# 18
# page_content='From CNN’s Mohammed Tawfeeq and Kareem Khadder' metadata={'source': 'cnn-live-news.html'}
# 46
# page_content='Hamas says it expects Israel to release around 200 Palestinian prisoners' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='prisoners on Saturday as part of the ceasefire and hostage deal' metadata={'source': 'cnn-live-news.html'}
# 63
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='“We are waiting for the list of Palestinian prisoners who are to be' metadata={'source': 'cnn-live-news.html'}
# 67
# page_content='are to be released tomorrow, which will include 120 prisoners with life' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='with life sentences, and 80 prisoners with high sentences, according to' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='to what was stipulated in the ceasefire agreement,” the Hamas Prisoners' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='Prisoners Media Office said in a statement Friday' metadata={'source': 'cnn-live-news.html'}
# 49
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Israel’s Justice Ministry is yet to release a list of names of Palestinian' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='prisoners to be released on Saturday or say how many will be freed' metadata={'source': 'cnn-live-news.html'}
# 66
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Link Copied!
#
# UNRWA must leave Jerusalem by January 30, Israel says' metadata={'source': 'cnn-live-news.html'}
# 67
# page_content='From CNN’s Dana Karni and Mohammed Tawfeeq' metadata={'source': 'cnn-live-news.html'}
# 42
# page_content='Barbed wire is seen in front of a sign, located at the entrance to' metadata={'source': 'cnn-live-news.html'}
# 66
# page_content='to Jerusalem branch of UNWRA, on October 29, 2024' metadata={'source': 'cnn-live-news.html'}
# 49
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='The UN’s agency for Palestinian refugees, UNRWA, has been told it must' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='it must leave its workplaces in Jerusalem by January 30' metadata={'source': 'cnn-live-news.html'}
# 55
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Israel’s UN ambassador Danny Danon said in a statement that the' metadata={'source': 'cnn-live-news.html'}
# 63
# page_content='that the development “came as a direct response to the acute national' metadata={'source': 'cnn-live-news.html'}
# 69
# page_content='national security risks posed by the widespread infiltration of UNRWA’s' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='UNRWA’s ranks” by Hamas and other groups “and the agency’s persistent' metadata={'source': 'cnn-live-news.html'}
# 69
# page_content='refusal to address the very grave and material concerns raised by Israel,' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='Israel, and to remedy this intolerable situation' metadata={'source': 'cnn-live-news.html'}
# 48
# page_content='.”' metadata={'source': 'cnn-live-news.html'}
# 2
# page_content='The ambassador’s remarks follow the passing of a bill in the Israeli' metadata={'source': 'cnn-live-news.html'}
# 68
# page_content='Israeli parliament in October 2024 that banned UNRWA from Israel and' metadata={'source': 'cnn-live-news.html'}
# 68
# page_content='and prohibited any contact between it and Israeli officials' metadata={'source': 'cnn-live-news.html'}
# 59
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Several countries, including the United States, have since expressed' metadata={'source': 'cnn-live-news.html'}
# 68
# page_content='expressed concern over the impact of the ban' metadata={'source': 'cnn-live-news.html'}
# 44
# page_content='. UNRWA has more than 13,000 employees stationed in Gaza alone' metadata={'source': 'cnn-live-news.html'}
# 62
# page_content='. In the West Bank and East Jerusalem, it employs nearly 4,000 workers.' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='UNRWA Commissioner-General Philippe Lazzarini warned the move “might' metadata={'source': 'cnn-live-news.html'}
# 68
# page_content='“might sabotage the Gaza ceasefire, failing once again the hopes of people' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='of people who have gone through unspeakable suffering' metadata={'source': 'cnn-live-news.html'}
# 53
# page_content='.”' metadata={'source': 'cnn-live-news.html'}
# 2
# page_content='“In only the first three days of the ceasefire, UNRWA brought in food for' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='food for 1 million people' metadata={'source': 'cnn-live-news.html'}
# 25
# page_content='. Our teams have already distributed food to around 300,000 people,' metadata={'source': 'cnn-live-news.html'}
# 67
# page_content='people, including in northern Gaza,” he said in a post on X' metadata={'source': 'cnn-live-news.html'}
# 59
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Israel has long sought to dismantle the UN body, arguing that some of its' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='of its employees are affiliated with Hamas, and that its schools teach' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='teach hate against Israel' metadata={'source': 'cnn-live-news.html'}
# 25
# page_content='. UNRWA has repeatedly denied these accusations , saying there is' metadata={'source': 'cnn-live-news.html'}
# 65
# page_content='there is “absolutely no ground for a blanket description of ‘the' metadata={'source': 'cnn-live-news.html'}
# 64
# page_content='of ‘the institution as a whole’ being ‘totally infiltrated' metadata={'source': 'cnn-live-news.html'}
# 58
# page_content='.’”' metadata={'source': 'cnn-live-news.html'}
# 3
# page_content='Link Copied!' metadata={'source': 'cnn-live-news.html'}
# 12
# page_content='What we know about the hostages expected to be released by Hamas today' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='From CNN's Dana Karni, Kareem Khadder, Ivana Kottasová, Eugenia Yosef and' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='Yosef and Jeremy Diamond' metadata={'source': 'cnn-live-news.html'}
# 24
# page_content='Left to right: Karina Ariev, Daniella Gilboa, Naama Levy, and Liri Albag.' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='Israel is preparing to receive four female soldiers held by Hamas on' metadata={'source': 'cnn-live-news.html'}
# 68
# page_content='Hamas on Saturday, in the latest release of captives under the Gaza' metadata={'source': 'cnn-live-news.html'}
# 67
# page_content='the Gaza ceasefire and hostage deal' metadata={'source': 'cnn-live-news.html'}
# 35
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='The militant group said Friday that it intends to release Karina Ariev,' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='Ariev, Daniella Gilboa, Naama Levy – all 20 years old – and Liri Albag, 19' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='The four women slated for release were among seven female soldiers' metadata={'source': 'cnn-live-news.html'}
# 66
# page_content='soldiers kidnapped from the Nahal Oz military base, where they served as' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='served as Israel Defense Forces military lookouts, observing activity' metadata={'source': 'cnn-live-news.html'}
# 69
# page_content='activity inside the Gaza Strip' metadata={'source': 'cnn-live-news.html'}
# 30
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Several videos showing their kidnapping became symbolic of the brutality' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='brutality of the Hamas attack of October 7, 2023' metadata={'source': 'cnn-live-news.html'}
# 48
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='One piece of footage showed them lined up against a wall, their hands' metadata={'source': 'cnn-live-news.html'}
# 69
# page_content='hands bound, their bodies bruised and bloodied' metadata={'source': 'cnn-live-news.html'}
# 46
# page_content='. The video was released by the women’s families in May to put pressure on' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='on the Israeli government to secure a deal to have them freed' metadata={'source': 'cnn-live-news.html'}
# 61
# page_content='. The IDF admitted at the time that it had failed to defend its personnel' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='personnel at the Nahal Oz base' metadata={'source': 'cnn-live-news.html'}
# 30
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Who is not included in the transfer: Israeli officials told the families' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='families of the four women that they intended to move forward with the' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='with the release this weekend — despite the fact that Israel had' metadata={'source': 'cnn-live-news.html'}
# 64
# page_content='had previously expected Arbel Yehud, a female civilian hostage still held' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='held in Gaza, to be included in Saturday’s release' metadata={'source': 'cnn-live-news.html'}
# 50
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Israel had demanded that Hamas release Yehud, a 29-year-old who was taken' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='was taken hostage from her home in Kibbutz Nir Oz, as part of the next' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='the next release, a source familiar with the matter said' metadata={'source': 'cnn-live-news.html'}
# 56
# page_content='. Yehud is believed to be held by Palestinian Islamic Jihad, not Hamas,' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='Hamas, which could be a factor in the timing of her release' metadata={'source': 'cnn-live-news.html'}
# 59
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Link Copied!' metadata={'source': 'cnn-live-news.html'}
# 12
# page_content='13-year-old boy among several Palestinians allegedly killed by Israeli' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='Israeli forces during ceasefire' metadata={'source': 'cnn-live-news.html'}
# 31
# page_content='From CNN's Zeena Saifi, Abeer Salman, Jeremy Diamond and Tareq ElHelou' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='Displaced Palestinians return to Rafah on Monday.' metadata={'source': 'cnn-live-news.html'}
# 49
# page_content='Thirteen-year-old Zakariya Barbakh had spent most of his life shuffling' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='shuffling between hospitals across Gaza, the occupied West Bank and Israel' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Born without a lung, he had struggled to breathe' metadata={'source': 'cnn-live-news.html'}
# 48
# page_content='. Doctors had predicted he would need a transplant if he were to reach' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='to reach adulthood' metadata={'source': 'cnn-live-news.html'}
# 18
# page_content='. But the last 15 months of war in Gaza had made that impossible.' metadata={'source': 'cnn-live-news.html'}
# 65
# page_content='When the ceasefire between Israel and Hamas went into effect on Sunday,' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='Sunday, Zakariya was ecstatic' metadata={'source': 'cnn-live-news.html'}
# 29
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='“Mom, now we can go look for my lungs!” his mother recalled him saying.' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='Less than 24 hours later, Zakariya was shot dead.' metadata={'source': 'cnn-live-news.html'}
# 49
# page_content='Doctors at Nasser Hospital say an Israeli sniper fired the fatal shot in' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='shot in the southern city of Rafah on Monday' metadata={'source': 'cnn-live-news.html'}
# 44
# page_content='. Zakariya’s family told CNN he had been looking for wood to use for' metadata={'source': 'cnn-live-news.html'}
# 68
# page_content='use for cooking and heating' metadata={'source': 'cnn-live-news.html'}
# 27
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='“He didn’t die from his disease; he ended up dying at the hands of the' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='of the occupation' metadata={'source': 'cnn-live-news.html'}
# 17
# page_content='. All he wanted was to have lungs to breathe, what did he do to deserve' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='deserve this? What did this child do?” his mother said, unable to hold' metadata={'source': 'cnn-live-news.html'}
# 70
# page_content='to hold back tears' metadata={'source': 'cnn-live-news.html'}
# 18
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='The Israeli military told CNN it was not aware of the incident.' metadata={'source': 'cnn-live-news.html'}
# 63
# page_content='Zakariya Barbakh was shot dead. The image has been blurred by CNN.' metadata={'source': 'cnn-live-news.html'}
# 66
# page_content='Zakariya is one of at least four Palestinians allegedly shot by the' metadata={'source': 'cnn-live-news.html'}
# 67
# page_content='by the Israeli military since the ceasefire went into effect' metadata={'source': 'cnn-live-news.html'}
# 60
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='The Israeli military has withdrawn to buffer zones along Gaza’s border,' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='border, but has warned Palestinians against approaching areas where its' metadata={'source': 'cnn-live-news.html'}
# 71
# page_content='where its troops are still stationed' metadata={'source': 'cnn-live-news.html'}
# 36
# page_content='. It has published a map of zones that are “very dangerous” to approach.' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='But where those zones begin and end is not always as clear on the ground.' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='“How would he know he would face occupation forces? How would he know he' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='know he was in the wrong area? All he did was try to find something to eat' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='. He got lost along the way' metadata={'source': 'cnn-live-news.html'}
# 27
# page_content='. Can you not see the way this child looks? He looks sick and despairing,”' metadata={'source': 'cnn-live-news.html'}
# 74
# page_content='his mother said' metadata={'source': 'cnn-live-news.html'}
# 15
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='A dramatic video showing the aftermath of the incident was shared widely' metadata={'source': 'cnn-live-news.html'}
# 72
# page_content='widely online' metadata={'source': 'cnn-live-news.html'}
# 13
# page_content='. CNN showed Zakariya’s family the video and his parents confirmed it was' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='it was their son' metadata={'source': 'cnn-live-news.html'}
# 16
# page_content='.' metadata={'source': 'cnn-live-news.html'}
# 1
# page_content='Link Copied!
#
# Ad Feedback
#
# Ad Feedback
#
# Ad Feedback
#
# Live TV Listen Watch' metadata={'source': 'cnn-live-news.html'}
# 73
# page_content='Watch Listen Live TV
#
# Follow CNN' metadata={'source': 'cnn-live-news.html'}
# 32
# page_content='© 2025 Cable News Network. A Warner Bros. Discovery Company' metadata={'source': 'cnn-live-news.html'}
# 59
# page_content='. All Rights Reserved. CNN Sans ™ & © 2016 Cable News Network.' metadata={'source': 'cnn-live-news.html'}
# 62

# %% [markdown]
# This is storing using chroma

# %%
#this is storing using chroma 
# Initialize the OpenAI embedding model
embedding_model = OpenAIEmbeddings(api_key="<OPENAI_API_TOKEN>", model='text-embedding-3-small')
# Create a Chroma vector store and embed the chunks
vector_store = Chroma.from_documents(
    documents=chunks,  # List of text chunks
    embedding=embedding_model,  # Embedding model
)

# %% [markdown]
# # COMPLETE RAG-CHAIN
#
# This section demonstrates the complete workflow of a Retrieval-Augmented Generation (RAG) chain, including document loading, text splitting, embedding generation, storage, and querying.
#
# 1. **Loading Documents**:
#     - HTML documents are loaded using `UnstructuredHTMLLoader`.
#
# 2. **Text Splitting**:
#     - The loaded documents are split into chunks using `RecursiveCharacterTextSplitter`.
#
# 3. **Embedding Generation**:
#     - Embeddings for the document chunks are generated using `OpenAIEmbeddings`.
#
# 4. **Storing Embeddings**:
#     - The generated embeddings are stored in Supabase.
#
# 5. **Querying Embeddings**:
#     - Relevant document chunks are retrieved based on a query using the stored embeddings.
#
# 6. **Generating Answers**:
#     - Answers are generated using the retrieved document chunks and `ChatOpenAI`.
#
# The following cells in this notebook demonstrate each step of the RAG chain in detail.

# %% [markdown]
# # Supabase Connection

# %%
from supabase import create_client, Client
from dotenv import load_dotenv
import os

# Load environment variables from a .env file
load_dotenv()

# Supabase connection setup
supabase_url = os.getenv("SUPABASE_URL")
supabase_key = os.getenv("SUPABASE_KEY")
supabase: Client = create_client(supabase_url, supabase_key)

# %% [markdown]
#  # Initialize OpenAI API

# %%
from langchain_openai import OpenAIEmbeddings, ChatOpenAI

# Replace with your actual API key
openai_api_key = os.getenv('OPENAI_API_KEY')

# Initialize the OpenAI embeddings model
embedding_model = OpenAIEmbeddings(api_key=openai_api_key, model='text-embedding-ada-002')

# Initialize the OpenAI chat model
llm = ChatOpenAI(api_key=openai_api_key, model="gpt-3.5-turbo")

# %% [markdown]
# # Load and Split Documents

# %%
from langchain_community.document_loaders import UnstructuredHTMLLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

def load_and_split_documents(file_path):
    """
    Load an HTML document from the specified file path and split it into chunks.

    Args:
        file_path (str): The path to the HTML file to be loaded.

    Returns:
        list: A list of document chunks, where each chunk is a string.
    """
    loader = UnstructuredHTMLLoader(file_path)
    data = loader.load()
    text_splitter = RecursiveCharacterTextSplitter(
        separators=['\n', '.', ' ', ''],
        chunk_size=75,
        chunk_overlap=10
    )
    return text_splitter.split_documents(data)

# Example Usage:
chunks = load_and_split_documents('mytvv-home.html')

# %% [markdown]
# # Generate and Store Embeddings

# %%
import json

# Function to insert embedding into Supabase
def insert_embedding(document, embedding, metadata={}):
    data = {
        "embedding": embedding,
        "document": document,
        "metadata": json.dumps(metadata)
    }
    response = supabase.table('vector_store').insert(data).execute()
    if response.data:
        print("Insertion successful")
    else:
        print(f"Error inserting: {response.error_message}")

# Function to generate and store embeddings for document chunks
def generate_and_store_embeddings(chunks, source="CNN live news"):
    for chunk in chunks:
        # Generate embedding for each chunk
        embedding = embedding_model.embed_query(chunk.page_content)
        # Insert the embedding into Supabase
        insert_embedding(chunk.page_content, embedding, {"source": source})
        print(f"Inserted document: {chunk.page_content[:50]}...")

# Example Usage:
generate_and_store_embeddings(chunks)
# Out:
# Insertion successful
# Inserted document: Henry Danger...
# Insertion successful
# Inserted document: Genre: Superhero, Comedy, Action Creator: Dana Ols...
# Insertion successful
# Inserted document: . Israel Original Run: July 26, 2014 - March 21, 2...
# Insertion successful
# Inserted document: Number of Seasons: 5 Number of Episodes: 121...
# Insertion successful
# Inserted document: At the beginning of the show, Henry explains how h...
# Insertion successful
# Inserted document: . He mentions how Captain Man's father, an irrespo...
# Insertion successful
# Inserted document: accidentally made him indestructible...
# Insertion successful
# Inserted document: . Henry wanted a simple after-school job and stumb...
# Insertion successful
# Inserted document: old store, which led him to becoming Captain Man's...
# Insertion successful
# Inserted document: ....
# Insertion successful
# Inserted document: Main Characters
#
# Henry Hart (Kid Danger)...
# Insertion successful
# Inserted document: Played by: Jace Norman Age: 13-18 (throughout the ...
# Insertion successful
# Inserted document: Brave, Loyal, Quick-witted...
# Insertion successful
# Inserted document: Captain Man...
# Insertion successful
# Inserted document: Played by: Cooper Barnes Age: Late 30s/Early 40s (...
# Insertion successful
# Inserted document: series) Personality: Confident, Heroic, Somewhat S...
# Insertion successful
# Inserted document: Charlotte Page...
# Insertion successful
# Inserted document: Played by: Riele Downs Age: 13-18 (throughout the ...
# Insertion successful
# Inserted document: Smart, Loyal, Sarcastic at times...
# Insertion successful
# Inserted document: Notable Episodes...
# Insertion successful
# Inserted document: Episode: "The Danger Begins" Season/Episode: 1/1 S...
# Insertion successful
# Inserted document: Hart lands a part-time job as Kid Danger, a superh...
# Insertion successful
# Inserted document: Captain Man...
# Insertion successful
# Inserted document: ....
# Insertion successful
# Inserted document: Episode: "I Know Your Secret" Season/Episode: 2/13...
# Insertion successful
# Inserted document: Man and Kid Danger's secret is almost exposed...
# Insertion successful
# Inserted document: ....

# %% [markdown]
# # Retrieve Relevant Chunks from Supabase

# %%
def retrieve_relevant_chunks(question, top_k=3):
    """
    Retrieve the most relevant document chunks for a given question.

    This function takes a question as input, generates an embedding for it using
    the embedding model, and then queries a database to find the top_k most relevant
    document chunks that match the question embedding.

    Args:
        question (str): The question for which relevant document chunks are to be retrieved.
        top_k (int, optional): The number of top matching document chunks to retrieve. Defaults to 3.

    Returns:
        list: A list of the top_k most relevant document chunks.
    """
    question_embedding = embedding_model.embed_query(question)
    response = supabase.rpc('match_documents', {
        'query_embedding': question_embedding,
        'match_count': top_k
    }).execute()
    return response.data

# Example Usage:
# relevant_chunks = retrieve_relevant_chunks("TELL ME ABOUT HENRY")

# %% [markdown]
# # Generate Answer using RAG

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnablePassthrough, RunnableSequence
from langchain_core.output_parsers import StrOutputParser

def generate_answer(question):
    # Retrieve relevant chunks
    relevant_chunks = retrieve_relevant_chunks(question)
    # Combine the content of the relevant chunks into a single context string
    context = "\n".join([chunk['document'] for chunk in relevant_chunks])

    # Define the prompt template for generating the answer
    prompt_template = PromptTemplate.from_template(
        "Answer the question based on the following context:\n\n{context}\n\nQuestion: {question}\nAnswer:"
    )

    # Create the RAG (Retrieval-Augmented Generation) pipeline
    rag_chain = RunnableSequence(
        {"context": RunnablePassthrough(), "question": RunnablePassthrough()},
        prompt_template,
        llm,
        StrOutputParser()
    )

    # Generate the answer using the RAG pipeline
    answer = rag_chain.invoke({"context": context, "question": question})
    return answer

# Example Usage:
question = " What is RAG?" 
answer = generate_answer(question)
print(f"Answer: {answer}")
# Out:
# Answer: I'm sorry, but without more specific information or context, I am unable to provide an accurate answer to the question "What is RAG?". Please provide more details or clarify the context so I can give you a relevant response.

# %%
from graphviz import Digraph
from IPython.display import display

def draw_rag_workflow():
    dot = Digraph("RAG Workflow", format="png")
    
    # Nodes
    dot.node("A", "Load & Split Documents")
    dot.node("B", "Generate & Store Embeddings")
    dot.node("C", "Retrieve Relevant Chunks")
    dot.node("D", "Generate Answer")
    dot.node("E", "LangGraph Integration (Upcoming)")
    
    # Edges
    dot.edge("A", "B")
    dot.edge("B", "C")
    dot.edge("C", "D")
    dot.edge("D", "E")
    
    # Render and display
    dot.render("rag_workflow")
    display(Image("rag_workflow.png"))

draw_rag_workflow()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\graphviz\backend\execute.py:78, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      77     else:
# ---> 78         proc = subprocess.run(cmd, **kwargs)
#      79 except OSError as e:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2288.0_x64__qbz5n2kfra8p0\Lib\subprocess.py:1538, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1537 try:
# -> 1538     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1539                              # no special security
#    1540                              None, None,
#    1541                              int(not close_fds),
#    1542                              creationflags,
#    1543                              env,
#    1544                              cwd,
#    1545                              startupinfo)
#    1546 finally:
#    1547     # Child is launched. Close the parent's copy of those pipe
#    1548     # handles that only the child should have open.  You need
#    (...)
#    1551     # pipe will not close when the child process exits and the
#    1552     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# The above exception was the direct cause of the following exception:
#
# ExecutableNotFound                        Traceback (most recent call last)
# Cell In[1], line 24
#      21     dot.render("rag_workflow")
#      22     display(Image("rag_workflow.png"))
# ---> 24 draw_rag_workflow()
#
# Cell In[1], line 21, in draw_rag_workflow()
#      18 dot.edge("D", "E")
#      20 # Render and display
# ---> 21 dot.render("rag_workflow")
#      22 display(Image("rag_workflow.png"))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\graphviz\_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\graphviz\rendering.py:122, in Render.render(self, filename, directory, view, cleanup, format, renderer, formatter, neato_no_op, quiet, quiet_view, outfile, engine, raise_if_result_exists, overwrite_source)
#     118 filepath = self.save(filename, directory=directory, skip_existing=None)
#     120 args.append(filepath)
# --> 122 rendered = self._render(*args, **kwargs)
#     124 if cleanup:
#     125     log.debug('delete %r', filepath)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\graphviz\_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\graphviz\backend\rendering.py:326, in render(engine, format, filepath, renderer, formatter, neato_no_op, quiet, outfile, raise_if_result_exists, overwrite_filepath)
#     322 cmd += args
#     324 assert filepath is not None, 'work around pytype false alarm'
# --> 326 execute.run_check(cmd,
#     327                   cwd=filepath.parent if filepath.parent.parts else None,
#     328                   quiet=quiet,
#     329                   capture_output=True)
#     331 return os.fspath(outfile)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\graphviz\backend\execute.py:81, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      79 except OSError as e:
#      80     if e.errno == errno.ENOENT:
# ---> 81         raise ExecutableNotFound(cmd) from e
#      82     raise
#      84 if not quiet and proc.stderr:
#
# ExecutableNotFound: failed to execute WindowsPath('dot'), make sure the Graphviz executables are on your systems' PATH

# %% [markdown]
# # SQL RAG FUNCTION

# %%
from dotenv import load_dotenv
import os

# Load environment variables from a .env file
load_dotenv()

# Retrieve the OpenAI API key from the environment variables
openai_api_key = os.getenv('OPENAI_API_KEY')

# %%
from langchain_core.prompts import ChatPromptTemplate

template = """
Based on the table schema below, write a SQL query that would answer the user's question:
{schema}

Question: {question}
SQL Query:
"""

prompt = ChatPromptTemplate.from_template(template)

# %%
prompt.format(schema="my schema", question="how many users are there?")
# Out:
# "Human: \nBased on the table schema below, write a SQL query that would answer the user's question:\nmy schema\n\nQuestion: how many users are there?\nSQL Query:\n"

# %%
from langchain_community.utilities import SQLDatabase

db_uri = "mysql+mysqlconnector://root:Vondabaic2020@localhost:3306/chinook"
db = SQLDatabase.from_uri(db_uri)

# %%
db.run("SELECT* FROM foodstuffs LIMIT 5;")
# Out:
# "[(1, 'Rice', 'Grains', Decimal('45.00'), 20, 'White long-grain rice, 5kg bag', 'https://images.pexels.com/photos/128756/pexels-photo-128756.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500', datetime.datetime(2025, 1, 27, 14, 34, 36)), (2, 'Wheat Flour', 'Grains', Decimal('30.00'), 15, 'High-quality whole wheat flour, 2kg', 'https://images.pexels.com/photos/128756/pexels-photo-128756.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500', datetime.datetime(2025, 1, 27, 14, 34, 36)), (3, 'Bananas', 'Fruits', Decimal('1.20'), 50, 'Fresh ripe bananas, sold per piece', 'https://images.pexels.com/photos/128756/pexels-photo-128756.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500', datetime.datetime(2025, 1, 27, 14, 34, 36)), (4, 'Oranges', 'Fruits', Decimal('1.50'), 40, 'Sweet and juicy oranges, sold per piece', 'https://images.pexels.com/photos/128756/pexels-photo-128756.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500', datetime.datetime(2025, 1, 27, 14, 34, 36)), (5, 'Chicken Breast', 'Meat', Decimal('12.99'), 25, 'Boneless and skinless chicken breast, 1kg', 'https://images.pexels.com/photos/128756/pexels-photo-128756.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500', datetime.datetime(2025, 1, 27, 14, 34, 36))]"

# %%
def get_schema(_):
    return db.get_table_info()

# %%
get_schema(None)
# Out:
# '\nCREATE TABLE foodstuffs (\n\tfood_id INTEGER NOT NULL AUTO_INCREMENT, \n\tfood_name VARCHAR(100) NOT NULL, \n\tcategory VARCHAR(50), \n\tprice DECIMAL(10, 2) NOT NULL, \n\tstock_quantity INTEGER NOT NULL, \n\tdescription TEXT, \n\timage_url VARCHAR(255), \n\tcreated_at TIMESTAMP NULL DEFAULT CURRENT_TIMESTAMP, \n\tPRIMARY KEY (food_id)\n)DEFAULT CHARSET=utf8mb4 COLLATE utf8mb4_0900_ai_ci ENGINE=InnoDB\n\n/*\n3 rows from foodstuffs table:\nfood_id\tfood_name\tcategory\tprice\tstock_quantity\tdescription\timage_url\tcreated_at\n1\tRice\tGrains\t45.00\t20\tWhite long-grain rice, 5kg bag\thttps://images.pexels.com/photos/128756/pexels-photo-128756.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=5\t2025-01-27 14:34:36\n2\tWheat Flour\tGrains\t30.00\t15\tHigh-quality whole wheat flour, 2kg\thttps://images.pexels.com/photos/128756/pexels-photo-128756.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=5\t2025-01-27 14:34:36\n3\tBananas\tFruits\t1.20\t50\tFresh ripe bananas, sold per piece\thttps://images.pexels.com/photos/128756/pexels-photo-128756.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=5\t2025-01-27 14:34:36\n*/'

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI

llm = ChatOpenAI()
sql_chain = (
    RunnablePassthrough.assign(schema = get_schema)
    | prompt
    | llm.bind(stop ="\nSQL Result:")
    | StrOutputParser()
)

# %%
sql_chain.invoke({"question":"how many rice are there"})
# Out:
# "SELECT stock_quantity\nFROM foodstuffs\nWHERE food_name = 'Rice';"

# %%
template = """ 
Based on the table schema below, question, sql query, and sql response, write a natural language response and respond like a cashier dont speak too much technical:
{schema}

Question: {question}
SQL Query: {query}
SQL Response: {response}
"""
prompt = ChatPromptTemplate.from_template(template)

# %%
def run_query(query):
    return db.run(query)

# %%
full_chain = (
    RunnablePassthrough.assign(query=sql_chain).assign(
        schema=get_schema,
        response=lambda variables: run_query(variables["query"])
    )
    | prompt
    | llm.bind(stop="\nNatural Language Response:")
)

# %%
full_chain.invoke({"question": "CAN I SEE THE RICE YOU HAVE  ?"})
# Out:
# AIMessage(content='Tablodan baktığım kadarıyla, elimizde beyaz uzun taneli pirinç var. 5 kiloluk paketlerde, fiyatı 45 TL. İsterseniz bakabilirsiniz.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 52, 'prompt_tokens': 517, 'total_tokens': 569, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-2c158971-6e3a-41a4-a943-ec63a3acfa4a-0', usage_metadata={'input_tokens': 517, 'output_tokens': 52, 'total_tokens': 569, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
